# %% [markdown]
# # 네이버 뉴스 API 연결해서 뉴스 스크래핑
# * 뉴스 홈페이지마다 각기 다른 태그로 본문을 구성하고 있음
# * 본문의 내용을 가져오기 위해서 모든 뉴스 홈페이지의 크롤링 코드를 작성하는 것은 불가능
# * 웹 스크래핑 & 기사 html 코드 분석
#     * webbaseloader 라이브러리를 이용해서 글자가 300자 이상인 것들은 본문으로 생각(광고 등 다른 text가 들어오는 것을 막음)
#     * 몇몇 기사에서 담화 형식의 기사를 내보내어 한 문단에 300자가 안되는 경우 발생
#     * 담화 형식은 광고의 제목과 비슷한 글자수로 구성되어 있어, 결국 본문이 쓰여있는 div를 찾는 것이 중요
#     * 본문이 담겨있는 특정 div에는 br태그나 p태그가 많은 것을 확인하여 이러한 태그가 가장 많은 하위 div 태그를 찾도록 코딩
#
# [참고 자료]
# * https://developers.naver.com/docs/serviceapi/search/blog/blog.md#%EA%B2%80%EC%83%89-api-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EA%B2%80%EC%83%89-%EA%B5%AC%ED%98%84-%EC%98%88%EC%A0%9C
# * https://contents.premium.naver.com/chatgpt/buff/contents/231204223117640hg

# %%
import urllib.request
import pandas as pd
import json
import re
import html

# 네이버 API의 클라이언트 ID와 시크릿 키 설정
MY_CLIENT_ID = "hZm0ny7bv69wAHcdYffq"
MY_CLIENT_SECRET = "pIyAPPtzD2"
CLIENT_ID = MY_CLIENT_ID  # 실제 클라이언트 ID를 입력하세요
CLIENT_SECRET = MY_CLIENT_SECRET  # 실제 클라이언트 시크릿을 입력하세요

# 검색할 키워드 목록
SEARCH_QUERIES = ["주식", "채권", "금융"]

# API 호출 시 설정
DISPLAY_COUNT = 100  # 한 페이지에 표시할 뉴스 항목 수
START_INDEX = 1  # 검색 결과의 시작 인덱스
END_INDEX = 300  # 검색 결과의 종료 인덱스
SORT_ORDER = "sim"  # 정렬 방식: "sim" (유사도) 또는 "date" (날짜)

# 뉴스 데이터를 저장할 데이터프레임 초기화
news_df = pd.DataFrame(columns=["Category", "Title", "Original Link", "Description", "Publication Date"])

def fetch_news(query):
    """
    주어진 검색어에 대해 뉴스 데이터를 가져와서 데이터프레임에 추가합니다.
    
    :param query: 검색어
    """
    global news_df
    encoded_query = urllib.parse.quote(query)  # 검색어를 URL 인코딩
    current_index = len(news_df)  # 현재 데이터프레임의 인덱스
    
    for start_index in range(START_INDEX, END_INDEX, DISPLAY_COUNT):
        url = f"https://openapi.naver.com/v1/search/news?query={encoded_query}&display={DISPLAY_COUNT}&start={start_index}&sort={SORT_ORDER}"
        
        try:
            request = urllib.request.Request(url)
            request.add_header("X-Naver-Client-Id", CLIENT_ID)
            request.add_header("X-Naver-Client-Secret", CLIENT_SECRET)
            response = urllib.request.urlopen(request)
            response_code = response.getcode()
            
            if response_code == 200:
                response_body = response.read()
                response_dict = json.loads(response_body.decode('utf-8'))
                items = response_dict['items']
                
                for item in items:
                    # HTML 태그 제거
                    clean_title = re.sub(re.compile('<.*?>'), '', item['title'])
                    clean_description = re.sub(re.compile('<.*?>'), '', item['description'])
                    clean_pub_date = re.sub(re.compile('<.*?>'), '', item['pubDate'])
                    
                    # 데이터프레임에 뉴스 항목 추가
                    news_df.loc[current_index] = [
                        query,  # 카테고리 추가
                        html.unescape(clean_title),  # HTML 엔티티 제거
                        html.unescape(item['originallink']),  # HTML 엔티티 제거
                        html.unescape(clean_description),
                        clean_pub_date
                    ]
                    current_index += 1
            else:
                print(f"Error Code: {response_code}")
                error_details = response.read().decode('utf-8')
                print(f"Error Details: {error_details}")

        except urllib.error.HTTPError as e:
            print(f"HTTPError: {e.code} - {e.reason}")
            error_details = e.read().decode('utf-8')
            print(f"Error Details: {error_details}")

# 각 검색어에 대해 뉴스 데이터 가져오기
for query in SEARCH_QUERIES:
    fetch_news(query)

# 데이터프레임을 CSV 파일로 저장
news_df.to_csv('news_data.csv', index=False)
print("CSV 파일이 'news_data.csv'로 저장되었습니다.")

# 데이터프레임 확인
news_df
# Out:
# CSV 파일이 'news_data.csv'로 저장되었습니다.
#     Category                                        Title  \
# 0         주식          국민연금, 비트코인 최다 보유 기업 주식 매입…460억 원 규모
# 1         주식                   국민연금이 460억 샀다...비트코인 대신 주식
# 2         주식      국민연금, 가상화폐 간접 투자… 美 비트코인 최다 보유 기업 주식 매입
# 3         주식        국민연금, 코인 간접 투자...비트코인 최다 보유 美기업 주식 매입
# 4         주식  국민연금, 비트코인 최다 보유 美마이크로스트래티지 주식 460억 원 규모 매입
# ..       ...                                          ...
# 895       금융                  토스뱅크, 고령층 대상 ‘디지털 금융 교육’ 실시
# 896       금융             토스뱅크, 금융취약계층 보호 위한 고령층 디지털 금융 교육
# 897       금융     하나금융그룹, 지난해 ESG 활동으로 5조 4072억원 사회적 가치 창출
# 898       금융                        은행 AI 혁신 막던 '망 분리' 폐지
# 899       금융            금리인하 기대에 '빚투' 다시 증가…6일새 4200억 '쑥'
#
#                                          Original Link  \
# 0    https://news.tvchosun.com/site/data/html_dir/2...
# 1    http://www.wowtv.co.kr/NewsCenter/News/Read?ar...
# 2    https://biz.chosun.com/international/internati...
# 3        http://www.fnnews.com/news/202408171033168529
# 4    https://www.nocutnews.co.kr/news/6197046?utm_s...
# ..                                                 ...
# 895  https://hobbyen-news.com/news/view/10655728043...
# 896  https://www.pointdaily.co.kr/news/articleView....
# 897  https://www.newsquest.co.kr/news/articleView.h...
# 898     https://www.hankyung.com/article/2024081314891
# 899  https://news.heraldcorp.com/view.php?ud=202408...
#
#                                            Description  \
# 0    마이크로스트레티지 주식 약 3400만 달러(460억 원) 상당을 매입했다고 보도했다...
# 1    마이크로스트래티지 주식을 매입했다고 보도했다. 마이크로스트래티지는 비트코인을 가장 ...
# 2    마이크로스트래티지 주식을 매입했다고 보도했다. 마이크로스트래티지는 비트코인을 가장 ...
# 3    마이크로스트래티지 주식을 매입했다고 보도했다. 마이크로스트래티지는 가장 많은 비트코...
# 4    마이크로스트래티지 주식을 매입했다고 보도했다. 마이크로스트래티지는 가장 많은 비트코...
# ..                                                 ...
# 895  토스뱅크가 비대면 금융 거래 확대로 인해 금융 서비스 이용에 어려움을 겪는 금융 취...
# 896  토스뱅크가 최근 서울 금천구에 위치한 서울시평생교육진흥원 서울시민대학 '모두의학교 ...
# 897  하나금융그룹이 지난 한 해 동안 환경‧사회‧지배구조 및 경제 간접 기여 등 각종 E...
# 898  앞으로 금융회사도 내부 PC에서 챗GPT 등 외부와 연결된 인공지능(AI) 서비스를...
# 899  17일 금융투자협회에 따르면, 주식 신용거래융자 잔고는 8일 17조1268억원에서 ...
#
#                     Publication Date
# 0    Sat, 17 Aug 2024 11:21:00 +0900
# 1    Sat, 17 Aug 2024 07:03:00 +0900
# 2    Sat, 17 Aug 2024 09:40:00 +0900
# 3    Sat, 17 Aug 2024 10:44:00 +0900
# 4    Sat, 17 Aug 2024 09:05:00 +0900
# ..                               ...
# 895  Fri, 16 Aug 2024 09:30:00 +0900
# 896  Fri, 16 Aug 2024 09:58:00 +0900
# 897  Fri, 16 Aug 2024 15:54:00 +0900
# 898  Tue, 13 Aug 2024 17:58:00 +0900
# 899  Sat, 17 Aug 2024 15:16:00 +0900
#
# [900 rows x 5 columns]

# %% [markdown]
# # 뉴스 링크에 접근해서 원문 스크래핑 (실패)
# p 태그인건 다 갖고오려고 했는데, 뭔가 뉴스 링크 들어가면 뉴스가 아니라 다른게 뜨는 듯...

# %%
import requests
from bs4 import BeautifulSoup

# 뉴스 내용 추출 함수
def extract_news_content(url):
    """
    주어진 URL에서 뉴스 내용을 추출합니다.
    :param url: 뉴스 URL
    :return: 추출된 뉴스 내용
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    paragraphs = soup.find_all('p')
    content = ' '.join([p.text for p in paragraphs])
    return content[:1000]  # 첫 1000자만 반환

# %%
import pandas as pd

# CSV 파일에서 데이터프레임으로 읽어오기
news_df = pd.read_csv('news_data.csv')

# 데이터프레임 확인
news_df['Original Link'][0]
# Out:
# 'https://www.hankyung.com/article/2024081288721'

# %%
# 뉴스 추출해보기
extract_news_content(news_df['Original Link'][0])
# Out:
# '한국경제 회원이 되어 보세요 지금 바로 한국경제 회원으로 가입하시고, 독점 혜택을 누려보세요 \n                        이미 회원이시면 로그인을 클릭해 주세요\n                      계정관리 마이뉴스 기자 구독 관리 마이증권 내 포트폴리오 관리 ⓒ 한경닷컴, 무단전재 및 재배포 금지 \n\n                                                                요양원 규제는 그대로…반쪽짜리 완화 비판도\n                                                            \n \n                                                            앞으로 보험회사가 방문 요양 서비스 시장에 직접 진출할 수 있게 된다. 지금까지는 자회사를 통해 제한적으로만 허용됐다. 다만 요양원 등 요양시설 사업은 여전히 진입 규제에 막혀 있어 일각에서는 ‘반쪽짜리&...\n                                                         \n\n                                                                "여행상품 구매자도 책임 있다"…커지는 티메프 환불 갈등\n                                                            \n \n                                                            티몬·위메프(티메프)의 여행상품과 상품권 환불 책임을 둘러싼 갈등이 커지고 있다. 환불금을 놓고 카드사와 전자지급결제대행(PG)사, 여행사 간 갈등이 불거진 가운데 소비자도 계약 상대방으로서 일정 부분 ...\n                                                         \n\n                                     '

# %% [markdown]
# # LangChain WebBaseLoader 활용 (반만 됨...-앵커와의 담화문 기사 같은 경우에는(0번 뉴스) 문장별로 개행이 되어있고 글이 짧아서 아무것도 안들어감)
# 한줄기의 희망!!! 전체 문서를 다 가져와줌 <br>
# 이걸 이용해서 개행문자 기준으로 나눴을 때, 글자 길이가 길면 본문으로 간주 <br>
# 글자 길이 : 300자 <br>
# (100자는 옆에 뜨는 광고도 다 가져오고, 너무 크면 가끔 문단을 나눈다고 p태그 여러개 적용해서 뉴스 기사 쓴 것들이 있어서 원문 소실됨)

# %%
# 요청실패와 피싱실패 예외 처리
# 태그 카운트 최적화
# 숨겨진 콘텐츠 무시

from bs4 import BeautifulSoup
import requests
import certifi
import logging

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

def extract_news_content(url):
    # 체크할 태그 목록 설정
    tags_to_check = ['br', 'p']
    
    # User-Agent 헤더 설정
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }
    
    try:
        # URL에서 HTML 콘텐츠 가져오기
        response = requests.get(url, headers=headers, verify=certifi.where())
        response.raise_for_status()  # HTTP 오류 확인
        response.encoding = 'utf-8'
        soup = BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')
    except requests.RequestException as e:
        logging.error(f"요청 실패: {e}")
        return None
    except Exception as e:
        logging.error(f"파싱 실패: {e}")
        return None
    
    max_tag_count = 0
    news_content_div = None

    # 하위 <div> 요소 개수 제한을 2에서 10까지 시도
    for div_limit in range(2, 10):
        for div in soup.find_all('div'):
            # 숨겨진 콘텐츠로 파싱 되는지 확인
            if div.get('style') and 'display:none' in div.get('style'):
                logging.error(f"콘텐츠 숨김으로 인한 파싱 불가 {url}")
            
            num_nested_divs = len(div.find_all('div'))
            if num_nested_divs >= div_limit:
                continue
            
            # 각 태그의 개수를 합산
            tag_count = sum(len(div.find_all(tag)) for tag in tags_to_check)
            
            # 태그 개수가 최대인 <div>를 찾음
            if tag_count > max_tag_count and len(div.get_text(strip=True)) >= 300:
                max_tag_count = tag_count
                news_content_div = div
        
        # 가장 많은 태그를 가진 <div>의 텍스트가 300자 이상인지 확인
        if news_content_div:
            content = news_content_div.get_text(strip=True)
            if len(content) >= 300:
                return content
    
    return None


# 예시 URL을 사용하여 함수 호출
url = news_df["Original Link"][0]
print(extract_news_content(url))
# Out:
# /TV조선 방송화면 캡처국민연금이 가상화폐에 대한 간접 투자를 확대하고 있다.코인 전문매체 코인데스크는 16일(현지시간) 최근 공개된 증권거래위원회(SEC) 자료를 인용해 국민연금이 올해 2분기에 마이크로스트레티지 주식 약 3400만 달러(460억 원) 상당을 매입했다고 보도했다.마이크로스트래티지는 가장 많은 비트코인을 보유한 회사다.약 2천만 개에 달하는 비트코인 전체 공급량의 1% 이상인 22만6500개를 보유 중이다.국민연금은 마이크로스트래티지가 이달 초 1대 10의 주식 분할 전에 평균 1377.48달러에 2만4500주를 매입했다.정확하게 3374만8260달러(약 457억 원) 규모다.주식 분할 후 국민연금이 보유한 주식 수는 24만5천 주로 늘었다.이날 종가(133.04달러) 기준 보유 금액은 3259만4800달러(약 441억 원)로 3.4% 손실을 기록 중이다.코인데스크는 "마이크로스트래티지가 코인 최대 기업 보유자인 만큼 국민연금의 주식 매입은 비트코인(BTC)에 대한 간접 투자로 볼 수 있다"고 전했다.국민연금이 가상화폐 관련 기업 주식을 매입한 것은 처음은 아니다.코인데스크에 따르면 국민연금은 미 가상화폐 거래소 코인베이스 주식 22만9807주도 보유하고 있다.국민연금은 지난해 코인베이스 주식을 평균 70.5달러에 28만2673주를 매입했다.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader(news_df['Original Link'][0])
docs = loader.load()
print(docs)
text = docs[0]
text
# Out:
# [Document(metadata={'source': 'https://biz.chosun.com/international/international_economy/2024/08/17/JDIT2LDAJBBTTPHPED53JUYGEE/?utm_source=naver&utm_medium=original&utm_campaign=biz', 'title': '국민연금, 가상화폐 간접 투자… 美 비트코인 최다 보유 기업 주식 매입 - 조선비즈', 'description': '국민연금, 가상화폐 간접 투자 美 비트코인 최다 보유 기업 주식 매입  국민연금이 가상화폐에 대한 간접 투자를 확대하고 있다. 코인 전문 매체 코인데스크는 16일현지 시각 최근 공개된 증권거래위원회SEC 증권 신고서를 인용해 국민연금이 올해 2분기 약 3400만달러46', 'language': 'ko'}, page_content='국민연금, 가상화폐 간접 투자… 美 비트코인 최다 보유 기업 주식 매입 - 조선비즈\n\n\n')]
# Document(metadata={'source': 'https://biz.chosun.com/international/international_economy/2024/08/17/JDIT2LDAJBBTTPHPED53JUYGEE/?utm_source=naver&utm_medium=original&utm_campaign=biz', 'title': '국민연금, 가상화폐 간접 투자… 美 비트코인 최다 보유 기업 주식 매입 - 조선비즈', 'description': '국민연금, 가상화폐 간접 투자 美 비트코인 최다 보유 기업 주식 매입  국민연금이 가상화폐에 대한 간접 투자를 확대하고 있다. 코인 전문 매체 코인데스크는 16일현지 시각 최근 공개된 증권거래위원회SEC 증권 신고서를 인용해 국민연금이 올해 2분기 약 3400만달러46', 'language': 'ko'}, page_content='국민연금, 가상화폐 간접 투자… 美 비트코인 최다 보유 기업 주식 매입 - 조선비즈\n\n\n')

# %%
from bs4 import BeautifulSoup
import requests
import certifi

def extract_news_content(url):
    # 체크할 태그 목록 설정 : 해당 태그가 많은 <div>가 뉴스콘텐츠가 있는 div
    tags_to_check = ['br', 'p']
    
    # 브라우저 User-Agent 설정
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }
    
    # URL에서 HTML 콘텐츠 가져오기
    response = requests.get(url, headers=headers, verify=certifi.where())
    response.encoding = 'utf-8'  # 적절한 인코딩으로 설정
    soup = BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')
    
    max_tag_count = 0
    news_content_div = None

    # 하위 div 요소 개수 제한을 2에서 시작하여 5까지 시도
    for div_limit in range(2, 10):
        for div in soup.find_all('div'):
            print(f"\n div_limit : {div_limit} 하위 div 요소 개수 : {len(div.find_all('div'))}")
            print(div)
            tag_count = 0
            
            # 각 태그의 개수를 합산
            for tag in tags_to_check:
                tag_count += len(div.find_all(tag))
            
            # 하위 div 요소 개수를 제한하고, 태그 개수가 최대인 div를 찾음
            if len(div.find_all('div')) < div_limit and tag_count > max_tag_count:
                max_tag_count = tag_count
                news_content_div = div
        
        # 가장 많은 지정된 태그를 가진 <div>의 텍스트가 300자 이상인지 확인
        if news_content_div and len(news_content_div.get_text(strip=True)) >= 300:
            return news_content_div.get_text(strip=True)
    
    # 만약 조건을 만족하는 div를 찾지 못했다면 None 반환
    return None

# Example usage
url = news_df["Original Link"][0]
print(extract_news_content(url))
# Out:
#  div_limit : 2 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 2 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 3 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 3 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 4 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 4 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 5 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 5 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 6 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 6 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 7 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 7 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 8 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 8 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
#
#  div_limit : 9 하위 div 요소 개수 : 1
# <div id="fusion-app"><div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div></div>
#
#  div_limit : 9 하위 div 요소 개수 : 0
# <div data-fusion-collection="layouts" data-fusion-message="Could not render component [layouts:article]" data-fusion-type="article" id="article" style="display:none"></div>
# None

# %%
from bs4 import BeautifulSoup
import requests
import certifi

def extract_news_content(url):
    # 체크할 태그 목록 설정 : 해당 태그가 많은 <div> 또는 <section> 등이 뉴스 콘텐츠가 있을 가능성이 큼
    tags_to_check = ['br', 'p']
    container_tags = ['div', 'section', 'article']  # 콘텐츠를 포함할 수 있는 태그들
    
    # 브라우저 User-Agent 설정
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'
    }
    
    # URL에서 HTML 콘텐츠 가져오기
    response = requests.get(url, headers=headers, verify=certifi.where())
    response.encoding = 'utf-8'  # 적절한 인코딩으로 설정
    soup = BeautifulSoup(response.content, 'html.parser', from_encoding='utf-8')
    
    max_tag_count = 0
    news_content_div = None
    
    # 하위 container_tag 요소 개수 제한을 2에서 10까지 시도
    for div_limit in range(2, 11):
        print(div_limit)
        for container_tag in container_tags:
            print(container_tag)
            for container in soup.find_all(container_tag):
                print("section: ",soup.find_all('section'))
                print("articles: ",soup.find_all('article'))
                tag_count = 0
                
                # 각 태그의 개수를 합산
                for tag in tags_to_check:
                    tag_count += len(container.find_all(tag))
                
                # 텍스트 길이를 기준으로 필터링
                text_length = len(container.get_text(strip=True))
                
                # 하위 요소 개수 제한과 텍스트 길이를 조건으로 사용
                if len(container.find_all(container_tag)) < div_limit and tag_count > max_tag_count and text_length >= 300:
                    max_tag_count = tag_count
                    news_content_div = container
            
        # 텍스트가 300자 이상인 콘텐츠를 찾은 경우 반환
        if news_content_div:
            return news_content_div.get_text(strip=True)
        print()
    # 조건을 만족하는 콘텐츠가 없을 경우 None 반환
    return None

# Example usage
url = news_df["Original Link"][0]
print(extract_news_content(url))
# Out:
# 2
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 3
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 4
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 5
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 6
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 7
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 8
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 9
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# 10
# div
# section:  []
# articles:  []
# section:  []
# articles:  []
# section
# article
#
# None

# %%
import pandas as pd
import logging

# 로그 설정: INFO 레벨의 로그를 콘솔에 출력
logging.basicConfig(level=logging.INFO, format='%(message)s')

# CSV 파일에서 데이터프레임으로 읽어오기
news_df = pd.read_csv('news_data.csv')

# 'content'라는 새로운 컬럼 생성
news_df['content'] = ""

# 링크에서 원문 모두 스크래핑하여 'content' 컬럼에 추가
for i in range(len(news_df)):
    url = news_df["Original Link"][i]
    try:
        news_df.at[i, 'content'] = extract_news_content(url)
    except requests.exceptions.RequestException as e:
        # 인증이 거부된 경우 로그 출력
        logging.info(f"{i} {url} 에서 인증을 거부했습니다. 에러 메시지: {str(e)}")

# 결과 확인
print(news_df.head())
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 135 https://www.newsen.com/news_view.php?uid=202408130752322410 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='www.newsen.com', port=443): Max retries exceeded with url: /news_view.php?uid=202408130752322410 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 378 https://vop.co.kr/A00001659511.html 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='vop.co.kr', port=443): Max retries exceeded with url: /A00001659511.html (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 409 http://www.sentv.co.kr/news/view/693149 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='www.sentv.co.kr', port=443): Max retries exceeded with url: /news/view/693149 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 577 https://vop.co.kr/A00001659255.html 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='vop.co.kr', port=443): Max retries exceeded with url: /A00001659255.html (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# 772 http://www.sentv.co.kr/news/view/693161 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='www.sentv.co.kr', port=443): Max retries exceeded with url: /news/view/693161 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# 818 http://www.sentv.co.kr/news/view/693159 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='www.sentv.co.kr', port=443): Max retries exceeded with url: /news/view/693159 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
# 827 https://vop.co.kr/A00001659461.html 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='vop.co.kr', port=443): Max retries exceeded with url: /A00001659461.html (Caused by SSLError(SSLError(1, '[SSL: DH_KEY_TOO_SMALL] dh key too small (_ssl.c:1007)')))
# 834 http://www.sentv.co.kr/news/view/693156 에서 인증을 거부했습니다. 에러 메시지: HTTPSConnectionPool(host='www.sentv.co.kr', port=443): Max retries exceeded with url: /news/view/693156 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
#   Category                                Title  \
# 0       주식  [경제PICK] 주식 시세처럼...실시간 '부동산 통계 시스템'
# 1       주식    [단독] 도이치 주식 최다 수익자, 윤 대통령 고액 후원했다
# 2       주식  애물단지 전락한 물납주식…상속인 되살 때 최대 50% 할인해준다
# 3       주식     30대그룹 공익법인, 계열사 보유주식 늘리고 기부액 줄였다
# 4       주식   정부, 안 팔리는 '물납주식', 상속인 다시 사도록 규제 푼다
#
#                                        Original Link  \
# 0  https://www.ytn.co.kr/_ln/0102_202408131715390968
# 1  https://www.ohmynews.com/NWS_Web/View/at_pg.as...
# 2     https://www.hankyung.com/article/202408142426i
# 3  https://www.newsis.com/view/NISX20240812_00028...
# 4  https://www.nocutnews.co.kr/news/6195658?utm_s...
#
#                   Publication Date  \
# 0  Tue, 13 Aug 2024 17:15:00 +0900
# 1  Wed, 14 Aug 2024 07:03:00 +0900
# 2  Wed, 14 Aug 2024 11:03:00 +0900
# 3  Tue, 13 Aug 2024 06:00:00 +0900
# 4  Wed, 14 Aug 2024 10:31:00 +0900
#
#                                              content
# 0  [앵커]주식 시세처럼, 실시간 부동산 통계 시스템! 시시각각 변하는 주가처럼 부동산...
# 1  큰사진보기▲도이치모터스ⓒ 연합뉴스관련사진보기검찰이 도이치모터스 주가조작 사건 종합의...
# 2  정부가 현금 대신 주식으로 수령한 상속세 물납주식의 매각 활성화를 위해 관련 제도를...
# 3  오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"...
# 4                                                 00

# %%
# 데이터프레임을 CSV 파일로 저장
news_df.to_csv('news_data.csv', index=False)
print("CSV 파일이 'news_data.csv'로 저장되었습니다.")
# Out:
# CSV 파일이 'news_data.csv'로 저장되었습니다.

# %%
# 글자 수가 300 이하인 content를 찾기
short_contents = news_df[news_df['content'].str.len() <= 300]

# 해당 행의 인덱스와 본문을 출력
for index, row in short_contents.iterrows():
    print(f"Index: {index}, Content: {row['content']}")
    print(news_df["Original Link"][index])
    print()
# Out:
# Index: 3, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002847314
#
# Index: 4, Content: 00
# https://www.nocutnews.co.kr/news/6195658?utm_source=naver&utm_medium=article&utm_campaign=20240814103039
#
# Index: 5, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240814046900009?input=1195m
#
# Index: 6, Content: 최상목 부총리, 15일 국유재산정책심의위 주재"국유재산 유지·보존→개발·활용, 국민 활용 적극 추진"노후청사·국유지 청년주택, 시니어 레지던스 등 공급물납주식 감액규정 신설, 투자형은 증권사가 주관토록등록 2024-08-14 오전 10:30:00수정 2024-08-14 오전 10:30:00가가
# http://www.edaily.co.kr/news/newspath.asp?newsid=02063126638987320
#
# Index: 7, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD0HPAD9V
#
# Index: 8, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408121857087656
#
# Index: 10, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002848141
#
# Index: 11, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002847112
#
# Index: 12, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408140912210784
#
# Index: 13, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081408333044324
#
# Index: 16, Content:
# https://magazine.hankyung.com/business/article/202408139625b
#
# Index: 18, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408131934587864
#
# Index: 19, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/economy/trend/5509874
#
# Index: 21, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812134000003?input=1195m
#
# Index: 24, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081315013797665
#
# Index: 26, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11091484
#
# Index: 27, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395140/?sc=Naver
#
# Index: 28, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523450&class=53&grp=
#
# Index: 29, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240814000326
#
# Index: 31, Content: 실시간 뉴스오늘의 증시코스피00000000-0.0%코스닥00000000-0.0%00.00 00:00 기준
# http://www.inews24.com/view/1752565
#
# Index: 33, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/economy/trend/5509134
#
# Index: 36, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081313014155501
#
# Index: 37, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812055300530?input=1195m
#
# Index: 38, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240814_0020486568
#
# Index: 40, Content: 실시간 주요기사“내 지갑 가져갔니?”…신림역 흉기살인, 오해가 부른 참극인가신유빈이 안아준 일본 탁구선수 “가미카제 박물관 가고파” 논란광복절에 기미가요·이승만 다큐를?…나사 빠진 KBS‘국민 여동생’에서 ‘믿고 보는 배우’로···드라마계 ‘굿파트너’가 된 장나라전현희 ‘김건희 살인자’, 정봉주 ‘명팔이’…초박빙 민주당 최고위원 경선 마지막 변수강원도 광복절 경축식도 파행···김진태 지사 “1948년 건국 부인은 정체성 훼손” 발언에 광복회원 항의하며 퇴장
# https://www.khan.co.kr/economy/economy-general/article/202408131033001
#
# Index: 42, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812117800002?input=1195m
#
# Index: 43, Content: 고객 제안 접수... 심사 통해 경품 제공국내·미국 주식 매매 시 추첨 통해 주식 지급
# https://www.meconomynews.com/news/articleView.html?idxno=98761
#
# Index: 44, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11092243
#
# Index: 45, Content: [토스증권 제공]
# https://www.dt.co.kr/contents.html?article_no=2024081202109963046004&ref=naver
#
# Index: 47, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/finance/general-stock/5508632
#
# Index: 48, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813020022516
#
# Index: 51, Content: 브라우저가 video 태그를 지원하지 않습니다.죄송하지만 다른 브라우저를 사용하여 주십시오.닫기
# http://www.yonhapnewstv.co.kr/MYH20240813023400641/?input=1825m
#
# Index: 53, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116713
#
# Index: 54, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813043200002?input=1195m
#
# Index: 56, Content: 한국경제 회원이 되어 보세요지금 바로 한국경제 회원으로 가입하시고, 독점 혜택을 누려보세요특별한 뉴스와 분석 보고서 접근주식 시장 및 경제 동향에 대한 최신 정보한경만의 독자적인 콘텐츠에 대한 접근이벤트 및 세미나 참가 기회이미 회원이시면로그인을 클릭해 주세요
# https://www.hankyung.com/article/202408142558i
#
# Index: 57, Content: 기재부 국유재산정책심의위원회…국유지에 있는 공립학교 증개축 허용10년간 국유지 활용한 청년주택 2.2만호 공급…창업기숙사 제공도
# http://www.newsfc.co.kr/news/articleView.html?idxno=66064
#
# Index: 60, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DCZNAXSDT
#
# Index: 61, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523391&class=53&grp=
#
# Index: 64, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD0HOMETH
#
# Index: 68, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=01312006638986992
#
# Index: 71, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11090857
#
# Index: 73, Content: 국세청(청장 강민수)은 국민들의 주식 양도소득세 신고·납부에 도움을 주기 위해 지난 5월 '주식과 세금' 책자를 발간한데 이어 올 상반기 주식 양도소득세 예정신고 시기에 맞춰 '주식 양도소득세 자주 실수하는 사례'를 제작·게재한다고 13일 밝혔다.국세청은 부동산 등을 포함하는 '양도소득세 실수사례' 시리즈를 연재하고 있으며, 이번에는 주식 관련 내용을 담았다.
# https://news.mtn.co.kr/news-detail/2024081218052637359
#
# Index: 77, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11090888
#
# Index: 78, Content: 2025년 국유재산종합계획, 물납주식 매각 활성화 심의·의결2035년까지 도심 임대 주택 최대 5만호 공급 목표 9월 발표물납주식 매각 활성화 우선매수제 및 투자형매각 제도 개선
# https://www.newsis.com/view/NISX20240813_0002848395
#
# Index: 80, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486109
#
# Index: 83, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD0104X7I
#
# Index: 84, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240814000357
#
# Index: 86, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812044500008?input=1195m
#
# Index: 87, Content: 삼성 노조, 또 '샌드위치 휴일 파업'... "사측에 피해 줄 수 있을 것"삼성 노조, 또 '샌드위치 휴일 파업'... "사측에 피해 줄 수 있을 것"삼성전자 최대 노조인 전국삼성전자노동조합(이하 전삼노)이 광복절인 15일부터 이달 18일까지 나흘간 게릴라성 파업에 들어갔다. 파업기간이 얄궂다. 15일부터 18일, 주말을 포함한 '샌드위치 연휴' 기간과 정확히 겹친다. 15일에는 휴일 근무를 거부하고 이후 변형교대, 4조3교대, 자율출퇴근제 등 다양한 방식을 동원해 파업 대오를 유지한다는 전략이다.샌드위...
# https://www.meconomynews.com/news/articleView.html?idxno=98668
#
# Index: 90, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240812_0020485109
#
# Index: 91, Content: "폭락장은 추가매수 기회"5兆 쓸어담은 '전투 개미'국내외 주식·채권 가리지 않고역대급 순매수…기관·외인과 대조
# https://www.hankyung.com/article/2024081288971
#
# Index: 97, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002846283
#
# Index: 98, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486121
#
# Index: 99, Content: 실시간 주요 뉴스이상민은 빚 타령 이혜정은 남편 욕…지겹다 지겨워장영란 "22억 빚 언급 후 부부싸움…♥한창 병원 적자 아냐"박위♥송지은, 결혼 앞두고 축하할 소식 전했다슈, 쌍둥이 딸 폭풍성장에 깜짝 "많이 컸네"'음주운전' BTS 슈가, 근무태만 진짜였나…"강사 무안하게 자버려"
# https://www.xportsnews.com/article/1892934
#
# Index: 101, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/world/usa-canada/5508942
#
# Index: 102, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163486
#
# Index: 104, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11091776
#
# Index: 107, Content: [사진 연합뉴스]
# https://www.dt.co.kr/contents.html?article_no=2024081202109963060008&ref=naver
#
# Index: 108, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116726
#
# Index: 109, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523392&class=7&grp=
#
# Index: 110, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.newscj.com/news/articleView.html?idxno=3168886
#
# Index: 112, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/finance/general-stock/5508252
#
# Index: 113, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/finance/general-stock/5508160
#
# Index: 114, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081209321252815
#
# Index: 115, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.econovill.com/news/articleView.html?idxno=663794
#
# Index: 116, Content: 브라우저가 video 태그를 지원하지 않습니다.죄송하지만 다른 브라우저를 사용하여 주십시오.닫기
# http://www.yonhapnewstv.co.kr/MYH20240813007900641/?input=1825m
#
# Index: 118, Content: 최신기사경제산업생활경제산업여행레저패션뷰티금융연예방송영화음악해외연예일반스포츠배구농구골프e스포츠격투기스포츠종합프로야구야구해외야구해외축구해외축구축구화제기자연재사진/영상연예스포츠영상돈버는퀴즈
# https://mydaily.co.kr/page/view/2024081215503207409
#
# Index: 120, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116228
#
# Index: 121, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002847538
#
# Index: 123, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812072100073?input=1195m
#
# Index: 124, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD0HRFK1J
#
# Index: 127, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020485530
#
# Index: 129, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.kbanker.co.kr/news/articleView.html?idxno=215954
#
# Index: 131, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408130959005196
#
# Index: 132, Content:
# https://www.mediapen.com/news/view/945046
#
# Index: 133, Content: For translation
# http://www.goodkyung.com/news/articleView.html?idxno=244352
#
# Index: 134, Content:
# https://magazine.hankyung.com/business/article/202408115987b
#
# Index: 135, Content:
# https://www.newsen.com/news_view.php?uid=202408130752322410
#
# Index: 136, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://news.bbsi.co.kr/news/articleView.html?idxno=3165837
#
# Index: 137, Content: 실시간 뉴스오늘의 증시코스피00000000-0.0%코스닥00000000-0.0%00.00 00:00 기준
# http://www.joynews24.com/view/1752378
#
# Index: 138, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.ftoday.co.kr/news/articleView.html?idxno=326995
#
# Index: 139, Content: 2024년 08월 16일 금요일서울27℃인천27℃백령25℃춘천26℃강릉23℃청주27℃수원25℃안동24℃울릉도26℃독도26℃대전26℃전주26℃광주25℃목포26℃여수27℃대구27℃울산25℃창원25℃부산26℃제주22℃
# https://www.newsway.co.kr/news/view?ud=2024081310592982200
#
# Index: 147, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408111551089882
#
# Index: 148, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240809054600002?input=1195m
#
# Index: 149, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.seoulfn.com/news/articleView.html?idxno=529357
#
# Index: 153, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.nbnews.kr/news/articleView.html?idxno=96501
#
# Index: 154, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.insightkorea.co.kr/news/articleView.html?idxno=207324
#
# Index: 155, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408120956193363
#
# Index: 157, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11091521
#
# Index: 158, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.ltn.kr/news/articleView.html?idxno=44554
#
# Index: 159, Content: (주)헤럴드주소:서울시 용산구 후암로4길 10 헤럴드스퀘어제호:헤럴드팝인터넷신문등록번호:서울 아03712등록일:2015년 04월 28일발행인ㆍ편집인:최진영청소년보호책임자:홍승완대표번호:02-727-0114온라인 뉴스룸:02-723-9623Copyright Herald Corporation. All Rights Reserved.
# http://biz.heraldcorp.com/view.php?ud=202408130752422365340_1
#
# Index: 160, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.bloter.net/news/articleView.html?idxno=621236
#
# Index: 163, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813025042670
#
# Index: 164, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.marketnews.co.kr/news/articleView.html?idxno=69387
#
# Index: 165, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=03601446638986992
#
# Index: 166, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD021XNNF
#
# Index: 167, Content: 순매수세에도 외인 보유 시총 852.6조…전월比 1.1%↓채권 2.9조 순매수…3.3조 만기상환에 두 달째 순회수
# http://www.shinailbo.co.kr/news/articleView.html?idxno=1916610
#
# Index: 168, Content: 브라우저가 video 태그를 지원하지 않습니다.죄송하지만 다른 브라우저를 사용하여 주십시오.닫기
# http://www.yonhapnewstv.co.kr/MYH20240814003700641/?input=1825m
#
# Index: 169, Content: 업무 효율을 높이고 보안을 강화하는AlphaKey[SINGLEX Live] LG의 전문가들과 함께 하는 <DX에서 AX로의 도약 : 구매, 제조/설비, R&D/품질>
# https://www.etnews.com/20240814000017
#
# Index: 170, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240814052200002?input=1195m
#
# Index: 171, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.smarttoday.co.kr/news/articleView.html?idxno=57360
#
# Index: 172, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=01866326638986664
#
# Index: 175, Content: 10월부터 매월 업계 관계자 회의 개최내년 3월까지 구체적 대책·과제 발표'최소 매매' 100주서 하향 검토상장사 주식분할 촉구도 다룰듯주주 제안 남발 등 상장사 부담 지적도
# https://www.sedaily.com/NewsView/2DCZL1796V
#
# Index: 176, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240809100700008?input=1195m
#
# Index: 177, Content: 토스증권 상반기 영업익 306억해외주식 브로커리지 성장 영향
# http://www.smedaily.co.kr/news/articleView.html?idxno=300429
#
# Index: 179, Content: 민족정론지 Fn투데이가 미디어 군자금을 모금합니다.(기간 : 5월30일 자정까지)대한민국의 국익을 위한  목소리를 냈다는 이유로 Fn투데이는 중국공산당과  법적으로 싸우고 있습니다.부정선거와 코로나19의 음모를 파헤치면서도 많은 공격을 받고 네이버와도 소송중입니다.Fn투데이가 위기를 기회로 바꿔 민족정론지, 세계적인 언론이 될 수 있게 도와주세요.후원바로가기
# http://www.fntoday.co.kr/news/articleView.html?idxno=330250
#
# Index: 180, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002848846
#
# Index: 181, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.whitepaper.co.kr/news/articleView.html?idxno=237050
#
# Index: 183, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240814020233223
#
# Index: 184, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002848059
#
# Index: 185, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.seoulfn.com/news/articleView.html?idxno=529224
#
# Index: 186, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/finance/general-stock/5508791
#
# Index: 189, Content: 동아닷컴주소 서울특별시 서대문구 충정로 29전화번호 02-360-0400등록번호 서울아00741발행일자 1996.06.18등록일자 2009.01.16발행·편집인 이명건
# https://www.donga.com/news/Economy/article/all/20240812/126491338/1
#
# Index: 191, Content: 한국경제 회원이 되어 보세요지금 바로 한국경제 회원으로 가입하시고, 독점 혜택을 누려보세요특별한 뉴스와 분석 보고서 접근주식 시장 및 경제 동향에 대한 최신 정보한경만의 독자적인 콘텐츠에 대한 접근이벤트 및 세미나 참가 기회이미 회원이시면로그인을 클릭해 주세요
# https://www.hankyung.com/article/202408066410Q
#
# Index: 194, Content: 젠슨 황 엔비디아 CEO. 〈사진=EPA·연합뉴스〉
# https://news.jtbc.co.kr/article/article.aspx?news_id=NB12209100
#
# Index: 195, Content: 한국일보에로그인하면 다양한편의 기능을제공 받을 수 있습니다.내 관심사대로 메인뉴스 설정구독한 콘텐츠 모아보기 제공주요기사와 추천, 활동내역 알림
# https://www.hankookilbo.com/News/Read/A2024081308040002690?did=NA
#
# Index: 196, Content: 시선 강탈 망사 드레스호주패션위크,'속 보이는 블랙 패션'켄달 제너..섹시 시스룩 드레스에 코르셋 노출 아찔'베를린 패션위크,'입었는데 다 보여'루나 비즐, '뇌쇄적인 눈빛'
# http://www.osen.co.kr/article/G1112395913
#
# Index: 197, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163477
#
# Index: 198, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240809_0002845022
#
# Index: 201, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.datasom.co.kr/news/articleView.html?idxno=201846
#
# Index: 202, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.efnews.co.kr/news/articleView.html?idxno=113954
#
# Index: 204, Content: 2024년 08월 16일 금요일서울27℃인천27℃백령25℃춘천26℃강릉23℃청주27℃수원25℃안동24℃울릉도26℃독도26℃대전26℃전주26℃광주25℃목포26℃여수27℃대구27℃울산25℃창원25℃부산26℃제주22℃
# https://www.newsway.co.kr/news/view?ud=2024081308013074776
#
# Index: 205, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.atstar1.com/news/articleView.html?idxno=6015832
#
# Index: 206, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240814_0002849745
#
# Index: 207, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240808084000009?input=1195m
#
# Index: 211, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.efnews.co.kr/news/articleView.html?idxno=113955
#
# Index: 212, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240807150200002?input=1195m
#
# Index: 215, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.kbanker.co.kr/news/articleView.html?idxno=215939
#
# Index: 216, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240808084051009?input=1195m
#
# Index: 218, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.mhns.co.kr/news/articleView.html?idxno=617400
#
# Index: 219, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002847644
#
# Index: 221, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240813000914
#
# Index: 223, Content: CJ프레시웨이 "국회 권고안 이행했는데"
# 공정위, 역대급 과징금 폭탄[5대 은행장 현미경ⓛ] 이재근 국민은행장
# 경영성적 맑음 3연임 촉각'스포츠 회담' 통했다
# CJ제일제당-쿠팡 '햇반 전쟁' 종전빗썸, 실명계좌 국민은행 환승 조짐
# "점유율 전쟁 격화 예고"
# https://www.megaeconomy.co.kr/news/newsview.php?ncode=1065576674041517
#
# Index: 224, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.cstimes.com/news/articleView.html?idxno=605766
#
# Index: 226, Content: 커뮤니티 글 작성을 위해 본인만의 특별한 필명을 등록하세요.최초 1회만 등록합니다.
# https://www.itooza.com/common/iview.php?no=2024081408061496706
#
# Index: 227, Content: м„ңмҡёмӢ л¬ём—җ лЎңк·ёмқён•ҳкім°Ёлі„нҷ”лҗң лүҙмҠӨлҘј л¬ҙлЈҢлЎң нҷ•мқён•ҳм„ёмҡ”!
# https://www.seoul.co.kr/news/economy/2024/08/06/20240806500117?wlog_tag3=naver
#
# Index: 229, Content: 기사의 가독성을 해치는 팝업, 백버튼 광고 등기타 수익성 광고를 지양하는클린미디어입니다.
# http://www.newsian.co.kr/news/articleView.html?idxno=72100
#
# Index: 232, Content: 글자크기 설정가가가가닫기
# https://www.mk.co.kr/article/11092296
#
# Index: 233, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/economy/trend/5510438
#
# Index: 239, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002849040
#
# Index: 241, Content: 정책·통화은행증권보험·카드시황·환율재테크일반
# https://www.ebn.co.kr/news/view/1633165/?sc=Naver
#
# Index: 243, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002849085
#
# Index: 245, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240808056300054?input=1195m
#
# Index: 246, Content: 최신기사오피니언사설사내칼럼사외칼럼매일희평정치정치일반지역정가정부·대통령실국회·정당북한·국방선거경제경제일반부동산금융·증권·보험산업·기업·창업구인·구직유통·IT·자동차사회사회일반사건사고법원·검찰교육보건·의료이웃사랑핫뉴스지역별 뉴스국제국제일반미국·중국·일본해외토픽문화문화일반음악·공연미술·전시문학·책종교스포츠스포츠일반파리올림픽야구축구농구골프지역스포츠연예연예일반영화방송·가요라이프라이프일반인사·화촉·모임·부음여행·축제맛건강독자펫운세포토·영상영상포토그래픽카드뉴스매일신문 RSS
# https://www.imaeil.com/page/view/2024081316461472033
#
# Index: 247, Content: 액셀러레이터 등록번호 : 제 2017-24호I사업자등록번호 : 211-88-48126I인터넷신문 등록번호: 서울, 아01225I제호 : 벤처스퀘어I발행일자 : 2014년 9월 1일 발행I등록일자 : 2010년 4월 29일, 편집인 : 명승은액셀러레이션 · 투자 · 미디어 · 서비스운영 · 투자조합 운영서울시 강남구 영동대로 646, 1604호 (위레벤646)경기도 성남시 분당구 대왕판교로 645번길 12, 5층Copyright © VENTURESQUARE. All Rights Reserved.
# https://www.venturesquare.net/936127
#
# Index: 248, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.econovill.com/news/articleView.html?idxno=663677
#
# Index: 249, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.psnews.co.kr/news/articleView.html?idxno=2063648
#
# Index: 250, Content: 민족정론지 Fn투데이가 미디어 군자금을 모금합니다.(기간 : 5월30일 자정까지)대한민국의 국익을 위한  목소리를 냈다는 이유로 Fn투데이는 중국공산당과  법적으로 싸우고 있습니다.부정선거와 코로나19의 음모를 파헤치면서도 많은 공격을 받고 네이버와도 소송중입니다.Fn투데이가 위기를 기회로 바꿔 민족정론지, 세계적인 언론이 될 수 있게 도와주세요.후원바로가기
# http://www.fntoday.co.kr/news/articleView.html?idxno=330314
#
# Index: 251, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813027192637
#
# Index: 253, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240807067300002?input=1195m
#
# Index: 256, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240814027900008?input=1195m
#
# Index: 257, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.foodneconomy.com/news/articleView.html?idxno=361469
#
# Index: 258, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408121826083278
#
# Index: 259, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=02728966638985680
#
# Index: 260, Content: (우) 07333 서울시 영등포구 여의대방로67길 9 (여의도동 44-33) 두일빌딩3층 | Tel : 02-761-6114 | Fax : 02-761-6163상호명 : (주)프라임경제 (제호:프라임경제) | 회장 : 이승찬 | 발행인 : 이종엽 | 편집인 : 이 호 | 청소년보호관리책임자 : 정호수인터넷신문 등록 No.서울,아00487      등록일자:2008년01월04일      발행일자:2005년10월01일Copyright ⓒ 2005 프라임경제 All rights reserved.
# http://www.newsprime.co.kr/news/article.html?no=650325
#
# Index: 261, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.getnews.co.kr/news/articleView.html?idxno=688138
#
# Index: 265, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240813001003
#
# Index: 269, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813028522434
#
# Index: 271, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.ccdailynews.com/news/articleView.html?idxno=2291133
#
# Index: 274, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408131811247895
#
# Index: 275, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163437
#
# Index: 277, Content: 아시아타임즈는 독자신뢰를 위해기자와데스크를 함께 공개하는'기사 책임제'를 시행하고 있습니다.데스크 :김지호증권부better502@asiatime.co.kr입력 :2024-08-13 16:21수정:2024-08-13 21:33
# https://www.asiatime.co.kr/article/20240813500362
#
# Index: 278, Content: 커뮤니티 글 작성을 위해 본인만의 특별한 필명을 등록하세요.최초 1회만 등록합니다.
# https://www.itooza.com/common/iview.php?no=2024081311103054490
#
# Index: 279, Content: мӮӯм ңн•ң лҢ“кёҖмқҖ лӢӨмӢң ліөкө¬н•  мҲҳ м—ҶмҠөлӢҲлӢӨ.к·ёлһҳлҸ„ мӮӯм ңн•ҳмӢңкІ мҠөлӢҲк№Ң?
# https://www.ngetnews.com/news/articleView.html?idxno=510593
#
# Index: 281, Content: 민족정론지 Fn투데이가 미디어 군자금을 모금합니다.(기간 : 5월30일 자정까지)대한민국의 국익을 위한  목소리를 냈다는 이유로 Fn투데이는 중국공산당과  법적으로 싸우고 있습니다.부정선거와 코로나19의 음모를 파헤치면서도 많은 공격을 받고 네이버와도 소송중입니다.Fn투데이가 위기를 기회로 바꿔 민족정론지, 세계적인 언론이 될 수 있게 도와주세요.후원바로가기
# http://www.fntoday.co.kr/news/articleView.html?idxno=330388
#
# Index: 282, Content: 실시간 주요기사“내 지갑 가져갔니?”…신림역 흉기살인, 오해가 부른 참극인가신유빈이 안아준 일본 탁구선수 “가미카제 박물관 가고파” 논란광복절에 기미가요·이승만 다큐를?…나사 빠진 KBS‘국민 여동생’에서 ‘믿고 보는 배우’로···드라마계 ‘굿파트너’가 된 장나라전현희 ‘김건희 살인자’, 정봉주 ‘명팔이’…초박빙 민주당 최고위원 경선 마지막 변수강원도 광복절 경축식도 파행···김진태 지사 “1948년 건국 부인은 정체성 훼손” 발언에 광복회원 항의하며 퇴장
# https://www.khan.co.kr/national/court-law/article/202408131605001
#
# Index: 283, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.newsculture.press/news/articleView.html?idxno=552816
#
# Index: 285, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=02194326638985680
#
# Index: 286, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240809054700051?input=1195m
#
# Index: 287, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408140000468446
#
# Index: 288, Content: * AI기술로 자동 요약된 내용입니다. 전체 맥락과 내용을 이해하기 위해서는  기사 본문 전체를 보시길 권장합니다정부가 국유지를 활용해 2035년까지 청년주택 2만2000호를 공급한다.물납주식 매각 활성화를 위해 우선매수제도 요건 완화와 투자형 매각 제도 개선도 추진하기로 했다.기획재정부는 14일 최상목 부총리 겸 기재부 장관 주재로 제26차 국유재산정책심의위원회를 열고 이 같은 내용을 담은 내년도 국유재산종합계획과 물납주식 매각 활성화 방안을 발표했다.닫기
# https://www.ajunews.com/view/20240814104356132
#
# Index: 289, Content: 삭제한 댓글은 다시복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.seoulfn.com/news/articleView.html?idxno=529183
#
# Index: 295, Content: 최신기사오피니언사설사내칼럼사외칼럼매일희평정치정치일반지역정가정부·대통령실국회·정당북한·국방선거경제경제일반부동산금융·증권·보험산업·기업·창업구인·구직유통·IT·자동차사회사회일반사건사고법원·검찰교육보건·의료이웃사랑핫뉴스지역별 뉴스국제국제일반미국·중국·일본해외토픽문화문화일반음악·공연미술·전시문학·책종교스포츠스포츠일반파리올림픽야구축구농구골프지역스포츠연예연예일반영화방송·가요라이프라이프일반인사·화촉·모임·부음여행·축제맛건강독자펫운세포토·영상영상포토그래픽카드뉴스매일신문 RSS
# https://www.imaeil.com/page/view/2024081409223603265
#
# Index: 296, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408130601424345
#
# Index: 298, Content: For translation
# http://www.goodkyung.com/news/articleView.html?idxno=244150
#
# Index: 299, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD01BJQRO
#
# Index: 301, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240813_0002848646
#
# Index: 302, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813104500004?input=1195m
#
# Index: 304, Content: 00
# https://www.nocutnews.co.kr/news/6195472?utm_source=naver&utm_medium=article&utm_campaign=20240813065229
#
# Index: 306, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD0HKC29G
#
# Index: 307, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116950
#
# Index: 308, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/society/general-society/5510140
#
# Index: 309, Content: 동아닷컴주소 서울특별시 서대문구 충정로 29전화번호 02-360-0400등록번호 서울아00741발행일자 1996.06.18등록일자 2009.01.16발행·편집인 이명건
# https://www.donga.com/news/Society/article/all/20240814/126516140/2
#
# Index: 310, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240814062600008?input=1195m
#
# Index: 311, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240812129800004?input=1195m
#
# Index: 312, Content: 티몬·위메프, 회생법원에 자구계획안 제시변제안 비롯한 회사의 정상화 방안 등 담겨소액 변제 방안 이견…티메프 측 "정정 예정"판매자 대표 "회사 정상 운영 등에 중점둘 것"다음 협의회는 오는 8월30일 오후 진행 예정
# https://www.newsis.com/view/NISX20240813_0002848954
#
# Index: 313, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813141300004?input=1195m
#
# Index: 315, Content: 티메프, 13일 첫 채권단과 협의나서소액우선변제 후 출자전환과 무상감자 제안채권단 "소액채권 우선 변제 대신 정상화에 투자"류화현 대표 "투자 비용 통해 정상화 방안 담을 것"등록 2024-08-13 오후 5:52:46수정 2024-08-13 오후 7:06:24가가
# http://www.edaily.co.kr/news/newspath.asp?newsid=03529286638986992
#
# Index: 316, Content: 티몬·위메프-채권단 협의 난항...재논의키로티메프 '소액 채권자 우선 변제' 제안…채권단 '회사 운영 정상화' 우선시인터넷입력 :2024/08/13 18:35    수정: 2024/08/13 19:50
# https://zdnet.co.kr/view/?no=20240813175128
#
# Index: 318, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395635/?sc=Naver
#
# Index: 319, Content: 서민지 기자,배한글 기자파이낸셜뉴스입력 2024.08.13 18:24수정 2024.08.13 21:16
# http://www.fnnews.com/news/202408131824000681
#
# Index: 320, Content: 실시간 주요기사“내 지갑 가져갔니?”…신림역 흉기살인, 오해가 부른 참극인가신유빈이 안아준 일본 탁구선수 “가미카제 박물관 가고파” 논란광복절에 기미가요·이승만 다큐를?…나사 빠진 KBS‘국민 여동생’에서 ‘믿고 보는 배우’로···드라마계 ‘굿파트너’가 된 장나라전현희 ‘김건희 살인자’, 정봉주 ‘명팔이’…초박빙 민주당 최고위원 경선 마지막 변수강원도 광복절 경축식도 파행···김진태 지사 “1948년 건국 부인은 정체성 훼손” 발언에 광복회원 항의하며 퇴장
# https://www.khan.co.kr/national/national-general/article/202408131940001
#
# Index: 328, Content: 서민지 기자,이정화 기자파이낸셜뉴스입력 2024.08.13 18:23수정 2024.08.13 18:55
# http://www.fnnews.com/news/202408131755263133
#
# Index: 329, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081312552897466
#
# Index: 330, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/photos/6824356
#
# Index: 332, Content: 12일 회생법원에 자구안 제출…사모펀드 투자유치 후 3년내 재매각자율합의 성사시 큐텐 등 구조조정 속도현실 가능성은 ‘글쎄’… 채권단 동의 ‘쉽지않아’합의 불발시 기업회생이 차선책등록 2024-08-12 오후 4:54:36수정 2024-08-12 오후 7:06:53가가
# http://www.edaily.co.kr/news/newspath.asp?newsid=02961846638986664
#
# Index: 334, Content: 닫기자동 추출 기술로 요약된 내용입니다.요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어,전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.
# http://www.kado.net/news/articleView.html?idxno=1260322
#
# Index: 335, Content: 서민지 기자,배한글 기자파이낸셜뉴스입력 2024.08.13 16:40수정 2024.08.13 16:59
# http://www.fnnews.com/news/202408131634519337
#
# Index: 336, Content: 00
# https://www.nocutnews.co.kr/news/6195348?utm_source=naver&utm_medium=article&utm_campaign=20240813044428
#
# Index: 337, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395650/?sc=Naver
#
# Index: 339, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=03260326638986664
#
# Index: 340, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/photos/6824315
#
# Index: 341, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/society/court-prosecution/5508579
#
# Index: 342, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081317445942071
#
# Index: 344, Content: 日 기시다, 총리 연임 포기 "내달 자민당 총재 선거 불출마"日 기시다, 총리 연임 포기 "내달 자민당 총재 선거 불출마"매일일보 = 조현정 기자 | 기시다 후미오 일본 총리가 오는 9월 치러지는 집권 자민당 총재 선거에 불출마한다고 밝혔다. 기시다 총리가 차기 자민당 총재 선거에 나서지 않으면서 총...
# http://www.m-i.kr/news/articleView.html?idxno=1149996
#
# Index: 345, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=01289046638986992
#
# Index: 347, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/society/court-prosecution/5508261
#
# Index: 351, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=03421046638986992
#
# Index: 352, Content: 시사
# 						>전체기사
# https://www.kmib.co.kr/article/view.asp?arcid=0020418612&code=61121111&cp=nv
#
# Index: 354, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD02H9LSJ
#
# Index: 355, Content: 한국일보에로그인하면 다양한편의 기능을제공 받을 수 있습니다.내 관심사대로 메인뉴스 설정구독한 콘텐츠 모아보기 제공주요기사와 추천, 활동내역 알림
# https://www.hankookilbo.com/News/Read/A2024081315290003973?did=NA
#
# Index: 358, Content: (우) 07333 서울시 영등포구 여의대방로67길 9 (여의도동 44-33) 두일빌딩3층 | Tel : 02-761-6114 | Fax : 02-761-6163상호명 : (주)프라임경제 (제호:프라임경제) | 회장 : 이승찬 | 발행인 : 이종엽 | 편집인 : 이 호 | 청소년보호관리책임자 : 정호수인터넷신문 등록 No.서울,아00487      등록일자:2008년01월04일      발행일자:2005년10월01일Copyright ⓒ 2005 프라임경제 All rights reserved.
# http://www.newsprime.co.kr/news/article.html?no=650711
#
# Index: 360, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116793
#
# Index: 361, Content: м„ңмҡёмӢ л¬ём—җ лЎңк·ёмқён•ҳкім°Ёлі„нҷ”лҗң лүҙмҠӨлҘј л¬ҙлЈҢлЎң нҷ•мқён•ҳм„ёмҡ”!
# https://www.seoul.co.kr/news/society/law/2024/08/13/20240813500235?wlog_tag3=naver
#
# Index: 362, Content: 브라우저가 video 태그를 지원하지 않습니다.죄송하지만 다른 브라우저를 사용하여 주십시오.닫기
# http://www.yonhapnewstv.co.kr/MYH20240813022700641/?input=1825m
#
# Index: 363, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/finance/general-stock/5508632
#
# Index: 366, Content:
# https://www.mediapen.com/news/view/945414
#
# Index: 368, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=03398086638986992
#
# Index: 369, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081214032642275
#
# Index: 370, Content: 동양·ABL생명 동시 매각 이뤄지나안방보험 파산…우리금융엔 '기회'
# http://www.smedaily.co.kr/news/articleView.html?idxno=300630
#
# Index: 372, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD00KY1X8
#
# Index: 373, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://it.chosun.com/news/articleView.html?idxno=2023092121478
#
# Index: 374, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813129251008?input=1195m
#
# Index: 377, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=03404646638986992
#
# Index: 378, Content:
# https://vop.co.kr/A00001659511.html
#
# Index: 379, Content: 서울신문에 로그인하고차별화된 뉴스를 무료로 확인하세요!
# https://www.seoul.co.kr/news/international/china/2024/08/13/20240813500186?wlog_tag3=naver
#
# Index: 387, Content: 매체정보03973 서울 마포구 월드컵북로 106 미디어타워 8층대표전화 : (02)326-5117팩스 : (02)326-5118제호 : 프레스맨등록번호 : 서울 아 02434등록일 : 2013-01-18발행일 : 2013-01-18발행·편집인 : 이석호편집국장 : 홍성인청소년보호책임자 : 김승종SSN 2636-1930Copyright © 2024 프레스맨.Allrights reserved. mail toadmin@pressman.kr
# https://www.pressman.kr/news/articleView.html?idxno=83668
#
# Index: 388, Content: 본 기사는 영어, 일본어, 중국어로 볼 수 있습니다.번역을 원한다면 해당 국가 국기 이모티콘을 클릭하시기 바랍니다.This news is available in English, Japanese, Chinese and Korean.For translation please click on the national flag emoticon.
# https://www.lcnews.co.kr/news/articleView.html?idxno=81971
#
# Index: 391, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.newscj.com/news/articleView.html?idxno=3168867
#
# Index: 392, Content: "폭락장은 추가매수 기회"5兆 쓸어담은 '전투 개미'국내외 주식·채권 가리지 않고역대급 순매수…기관·외인과 대조
# https://www.hankyung.com/article/2024081288971
#
# Index: 393, Content: 큐텐테크놀로지 등 대상 '채권가압류' 신청 인용
# https://www.bloter.net/news/articleView.html?idxno=621162
#
# Index: 395, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813121300009?input=1195m
#
# Index: 399, Content: [사진 연합뉴스]
# https://www.dt.co.kr/contents.html?article_no=2024081202109963060008&ref=naver
#
# Index: 402, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523418&class=42&grp=
#
# Index: 405, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.asiaa.co.kr/news/articleView.html?idxno=182774
#
# Index: 406, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.businessplus.kr/news/articleView.html?idxno=67331
#
# Index: 407, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DCZMVG1YT
#
# Index: 409, Content:
# http://www.sentv.co.kr/news/view/693149
#
# Index: 410, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=01377606638986992
#
# Index: 411, Content: 외인, 장 중 3·10년 국채선물 순매도국고채 3년물 금리, 2.7bp 내린 2.888%“7월 CPI, PPI보단 높게 나올 것으로 전망”미국채 10년물 금리, 아시아 장서 0.1bp↑등록 2024-08-14 오후 12:03:39수정 2024-08-14 오후 12:03:39가가
# http://www.edaily.co.kr/news/newspath.asp?newsid=02397686638987320
#
# Index: 412, Content: 간밤 미국채 10년물 금리 6bp 하락9월 FOMC서 50bp 인하 가능성 53.5%채권 대차잔고, 3거래일 연속 감소세122.1조원대로 연중 최저치 경신장 마감 후 미 7월 소비자물가지수 발표등록 2024-08-14 오전 8:36:48수정 2024-08-14 오전 8:36:48가가
# http://www.edaily.co.kr/news/newspath.asp?newsid=01577686638987320
#
# Index: 414, Content: 티몬·위메프, 정산시스템 개편·구조조정 등 자구안..채권단 이견
# http://kpenews.com/View.aspx?No=3333071
#
# Index: 415, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.srtimes.kr/news/articleView.html?idxno=161073
#
# Index: 419, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.newsdream.kr/news/articleView.html?idxno=65618
#
# Index: 423, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.ksilbo.co.kr/news/articleView.html?idxno=1006314
#
# Index: 424, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813104551004?input=1195m
#
# Index: 425, Content: 정책·통화은행증권보험·카드시황·환율재테크일반
# https://www.ebn.co.kr/news/view/1633386/?sc=Naver
#
# Index: 430, Content: 신문사소개기사제보광고문의개인정보취급방침청소년보호정책이메일무단수집거부인터넷신문윤리강령빅데이터뉴스(The BigData)  | 발행인:임경오 | 편집인:임경오 | 청소년보호책임자:박정배주소: 서울 영등포구 국회대로68길 23 정원빌딩 501호 (우편번호:07237)| 전화:02-2235-3738 | 팩스:02-2235-3739정기간행물 등록번호: 서울 아04807 | 창간연월일:2012년 9월 18일Copyright ⓒ 2012 빅데이터뉴스. All rights reserved.
# http://www.thebigdata.co.kr/view.php?ud=20240730145811474862abca1943_23
#
# Index: 431, Content: 양현우 기자hunwoo684@opinionnews.co.kr저작권자 © 오피니언뉴스 무단전재 및 재배포 금지
# http://www.opinionnews.co.kr/news/articleView.html?idxno=103509
#
# Index: 437, Content: 브라우저가 video 태그를 지원하지 않습니다.죄송하지만 다른 브라우저를 사용하여 주십시오.닫기
# http://www.yonhapnewstv.co.kr/MYH20240814003700641/?input=1825m
#
# Index: 438, Content: 기사의 가독성을 해치는 팝업, 백버튼 광고 등기타 수익성 광고를 지양하는클린미디어입니다.
# http://www.newsian.co.kr/news/articleView.html?idxno=72125
#
# Index: 439, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240808053200008?input=1195m
#
# Index: 440, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002847219
#
# Index: 441, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.bloter.net/news/articleView.html?idxno=621355
#
# Index: 442, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408111451169265
#
# Index: 443, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.4th.kr/news/articleView.html?idxno=2067708
#
# ...
# http://news.mt.co.kr/mtview.php?no=2024081309493111287
#
# Index: 776, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395892/?sc=Naver
#
# Index: 780, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523391&class=53&grp=
#
# Index: 782, Content: 두근두근핫포토"잘 있었지?"차에 불이금의환향파리 미아(?)
# http://www.edaily.co.kr/news/newspath.asp?newsid=02778166638986992
#
# Index: 783, Content: 최신기사경제산업생활경제산업여행레저패션뷰티금융연예방송영화음악해외연예일반스포츠배구농구골프e스포츠격투기스포츠종합프로야구야구해외야구해외축구해외축구축구화제기자연재사진/영상연예스포츠영상돈버는퀴즈
# https://mydaily.co.kr/page/view/2024081311170965242
#
# Index: 784, Content: 금융권 망분리 규제 특례 시행…생성형AI 활용 가능해진다금융감독당국 단계별 추진 목표 제시…'디지털 금융보안법' 추진도금융입력 :2024/08/13 14:00
# https://zdnet.co.kr/view/?no=20240813104030
#
# Index: 785, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.srtimes.kr/news/articleView.html?idxno=161115
#
# Index: 787, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081322410867199
#
# Index: 788, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240809_0002845039
#
# Index: 789, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240814000247
#
# Index: 791, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD02HLD3V
#
# Index: 792, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.econovill.com/news/articleView.html?idxno=663798
#
# Index: 793, Content: 실시간 주요기사“내 지갑 가져갔니?”…신림역 흉기살인, 오해가 부른 참극인가신유빈이 안아준 일본 탁구선수 “가미카제 박물관 가고파” 논란광복절에 기미가요·이승만 다큐를?…나사 빠진 KBS‘국민 여동생’에서 ‘믿고 보는 배우’로···드라마계 ‘굿파트너’가 된 장나라전현희 ‘김건희 살인자’, 정봉주 ‘명팔이’…초박빙 민주당 최고위원 경선 마지막 변수강원도 광복절 경축식도 파행···김진태 지사 “1948년 건국 부인은 정체성 훼손” 발언에 광복회원 항의하며 퇴장
# https://www.khan.co.kr/national/national-general/article/202408131135001
#
# Index: 795, Content: 코스콤 본사 전경. [코스콤 제공]
# https://www.dt.co.kr/contents.html?article_no=2024081302109963060006&ref=naver
#
# Index: 797, Content: A시중은행, 지주회장의 친인척 법인에 대규모 부당대출회장 친인척이 허위서류 제출했는데도 은행은 대출 실행법인 담보가치 전무한데…신용도 올려주고 20억 대출 내줘용도외유용 이력 있는데도 본점 승인없이 지점전결로 대출금감원 "은행 엄정 제재…차주는 문서위조·사기혐의로 수사기관 통보"
# https://www.newsis.com/view/NISX20240809_0002845075
#
# Index: 798, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163583
#
# Index: 800, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.bloter.net/news/articleView.html?idxno=621353
#
# Index: 801, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240814_0002849483
#
# Index: 802, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395496/?sc=Naver
#
# Index: 803, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240814021443471
#
# Index: 804, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163906
#
# Index: 808, Content: 주소 : 서울 서초구 강남대로 315전화 : 02-2003-7114인터넷신문 등록번호 : 서울 아04510등록일자 : 2017.05.08Copyright ⓒ파이낸셜뉴스. All rights reserved.
# http://www.fnnews.com/news/202408121840318362
#
# Index: 810, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240812_0001626495
#
# Index: 811, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.startuptoday.co.kr/news/articleView.html?idxno=327791
#
# Index: 813, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395594/?sc=Naver
#
# Index: 814, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.psnews.co.kr/news/articleView.html?idxno=2063768
#
# Index: 816, Content: 신문사소개기사제보광고문의개인정보취급방침청소년보호정책이메일무단수집거부인터넷신문윤리강령빅데이터뉴스(The BigData)  | 발행인:임경오 | 편집인:임경오 | 청소년보호책임자:박정배주소: 서울 영등포구 국회대로68길 23 정원빌딩 501호 (우편번호:07237)| 전화:02-2235-3738 | 팩스:02-2235-3739정기간행물 등록번호: 서울 아04807 | 창간연월일:2012년 9월 18일Copyright ⓒ 2012 빅데이터뉴스. All rights reserved.
# http://www.thebigdata.co.kr/view.php?ud=20240814101338515762abca1943_23
#
# Index: 817, Content: [프라임경제] KB증권은 고액자산가(HNW) 고객들의 초등학생 자녀를 대상으로 '키즈 금융 썸머 아카데미'를 실시했다고 13일 밝혔다.
# http://www.newsprime.co.kr/news/article.html?no=650725
#
# Index: 818, Content:
# http://www.sentv.co.kr/news/view/693159
#
# Index: 819, Content: 전국 각지의 농협은행 주거래 기업 방문해 맞춤형 콘텐츠 제공 서비스논산 훈련소 전역 예정자 대상 금융지식 함양, 이해도 높여
# https://www.dailysmart.co.kr/news/articleView.html?idxno=91323
#
# Index: 820, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240809_0002844933
#
# Index: 821, Content: 신문사소개기사제보광고문의개인정보취급방침청소년보호정책이메일무단수집거부인터넷신문윤리강령빅데이터뉴스(The BigData)  | 발행인:임경오 | 편집인:임경오 | 청소년보호책임자:박정배주소: 서울 영등포구 국회대로68길 23 정원빌딩 501호 (우편번호:07237)| 전화:02-2235-3738 | 팩스:02-2235-3739정기간행물 등록번호: 서울 아04807 | 창간연월일:2012년 9월 18일Copyright ⓒ 2012 빅데이터뉴스. All rights reserved.
# http://www.thebigdata.co.kr/view.php?ud=20240814100637191862abca1943_23
#
# Index: 822, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.onews.tv/news/articleView.html?idxno=215946
#
# Index: 823, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163631
#
# Index: 825, Content: 업무 효율을 높이고 보안을 강화하는AlphaKey[SINGLEX Live] LG의 전문가들과 함께 하는 <DX에서 AX로의 도약 : 구매, 제조/설비, R&D/품질>
# https://www.etnews.com/20240813000290
#
# Index: 826, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/GYH20240813000600044?input=1363m
#
# Index: 827, Content:
# https://vop.co.kr/A00001659461.html
#
# Index: 828, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240814021700002?input=1195m
#
# Index: 830, Content: 핀포인트뉴스매체정보등록번호 : 서울 아 05122등록일 : 2018-04-19발행일 : 2018-05-20제호 : 핀포인트뉴스발행인 : 임지혜편집인 : 김순환편집국장 : 신홍범청소년보호책임자 : 김남규
# https://www.pinpointnews.co.kr/news/articleView.html?idxno=282109
#
# Index: 831, Content: 제호:로이슈 | 정기간행물 등록번호:서울 아00830 | 창간연월일:2005년 11월 1일대표이사:김영삼 | 발행인/편집인:김영삼 | 청소년보호책임자:편도욱주소:서울 영등포구 국회대로 70길 22  금강빌딩 705호전화:02-6925-0217Copyright ⓒ 2013 로이슈. All rights reserved. e-mail : law@lawissue.co.kr
# http://www.lawissue.co.kr/view.php?ud=2024081314182621399817d053b9_12
#
# Index: 832, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002846281
#
# Index: 833, Content: 최신기사경제산업생활경제산업여행레저패션뷰티금융연예방송영화음악해외연예일반스포츠배구농구골프e스포츠격투기스포츠종합프로야구야구해외야구해외축구해외축구축구화제기자연재사진/영상연예스포츠영상돈버는퀴즈
# https://mydaily.co.kr/page/view/2024081308144290401
#
# Index: 834, Content:
# http://www.sentv.co.kr/news/view/693156
#
# Index: 835, Content: 연대-삼성 금융리더 6기를 이수한 삼성생명 컨설턴트 52명 및 관계자들이 지난 12일 서울 연세대학교 백양누리 그랜드볼룸에서 수료식 기념촬영을 하고 있다. <삼성생명 제공>
# https://www.dt.co.kr/contents.html?article_no=2024081302109963084001&ref=naver
#
# Index: 836, Content: 정책·통화은행증권보험·카드시황·환율재테크일반
# https://www.ebn.co.kr/news/view/1633373/?sc=Naver
#
# Index: 840, Content:
# http://www.joseilbo.com/news/news_read.php?uid=523374&class=18&grp=
#
# Index: 841, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813026513008
#
# Index: 843, Content: 이승연 기자,서혜진 기자파이낸셜뉴스입력 2024.08.13 18:14수정 2024.08.13 18:27
# http://www.fnnews.com/news/202408131814072311
#
# Index: 844, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.delighti.co.kr/news/articleView.html?idxno=84709
#
# Index: 845, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.getnews.co.kr/news/articleView.html?idxno=688314
#
# Index: 847, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240813000824
#
# Index: 848, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002846217
#
# Index: 849, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486038
#
# Index: 850, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486039
#
# Index: 852, Content: 컨설턴트 산학연계 과정 '연대-삼성 금융리더' 6기 수료식 가져고객에게 최상의 금융 서비스 제공을 위한 금융전문가 육성
# http://www.wikileaks-kr.org/news/articleView.html?idxno=156870
#
# Index: 854, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1394872/?sc=Naver
#
# Index: 855, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240813120000530?input=1195m
#
# Index: 856, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.seoulwire.com/news/articleView.html?idxno=618475
#
# Index: 857, Content: ※ 여러분의 제보가 뉴스가 됩니다. 각종 비리와 부당대우, 사건사고와 미담, 소비자 고발 등 모든 얘깃거리를 알려주세요이메일 :webmaster@enewstoday.co.kr카카오톡 : @이뉴스투데이
# http://www.enewstoday.co.kr/news/articleView.html?idxno=2163478
#
# Index: 859, Content: 권력에 타협하지 않는 언론,한겨레 후원회원이 되어주세요
# https://www.hani.co.kr/arti/economy/economy_general/1153546.html
#
# Index: 860, Content: 대표이사/발행인/편집인 : 이영섭|편집국장 : 채원배|주소 : 서울시 종로구 종로 47 (공평동,SC빌딩17층)|사업자등록번호 : 101-86-62870|고충처리인 : 김성환|청소년보호책임자 : 안병길|통신판매업신고 : 서울종로 0676호|등록일 : 2011. 05. 26|제호 : 뉴스1코리아(읽기: 뉴스원코리아)|대표 전화 : 02-397-7000|대표 이메일 :webmaster@news1.kr
# https://www.news1.kr/local/busan-gyeongnam/5509859
#
# Index: 862, Content: 제호 : 세계일보서울특별시 용산구 서빙고로 17등록번호 : 서울, 아03959등록일(발행일) : 2015년 11월 2일발행인 : 정희택편집인 : 황정미전화번호 : 02-2000-1234청소년보호 책임자 : 임인섭Copyright ⓒ 세계일보 All rights reserved.
# http://www.segye.com/newsView/20240813518969?OutUrl=naver
#
# Index: 863, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240813000831
#
# Index: 864, Content: 2024년 08월 16일 금요일서울27℃인천27℃백령25℃춘천26℃강릉23℃청주27℃수원25℃안동24℃울릉도26℃독도26℃대전26℃전주26℃광주25℃목포26℃여수27℃대구27℃울산25℃창원25℃부산26℃제주22℃
# https://www.newsway.co.kr/news/view?ud=2024081315324921124
#
# Index: 866, Content: 생활/문화건강정보자동차/시승기도로/교통여행/레저음식/맛집패션/뷰티공연/전시책종교날씨생활문화일반
# https://www.dailian.co.kr/news/view/1395271/?sc=Naver
#
# Index: 868, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.straightnews.co.kr/news/articleView.html?idxno=251901
#
# Index: 870, Content: 실시간 뉴스오늘의 증시코스피00000000-0.0%코스닥00000000-0.0%00.00 00:00 기준
# http://www.inews24.com/view/1752586
#
# Index: 871, Content: 정책·통화은행증권보험·카드시황·환율재테크일반
# https://www.ebn.co.kr/news/view/1633353/?sc=Naver
#
# Index: 874, Content: 회원님은부터“asdf”를 구독하고 계십니다.아래 ‘구독취소’ 버튼을 클릭해서 구독을 ‘취소’하실 수 있습니다.해당 구독 취소의 효과는 “”에 한정되며, 서울경제 뉴스레터 수신에 대한 설정값이나 다른 뉴스레터 수신여부에는 영향을 끼치지 않습니다.
# https://www.sedaily.com/NewsView/2DD02FHC1Z
#
# Index: 875, Content: 매체정보㈜ 한국아이닷컴주소 : 서울시 마포구 월드컵북로56길 19 (상암동, 드림타워 10층)대표번호 : 02) 6388-8000등록번호 : 서울 아03360등록일 : 2014-10-10발행·편집인 : 조상현발행일 : 2014-05-19청소년보호책임자 : 강영임한국아이닷컴의 모든 콘텐츠는 저작권법의 보호를 받는바, 무단 전재·복사·배포 등은 법적제재를 받을 수 있습니다.Copyright © 2024 데일리한국.Allrights reserved.
# https://daily.hankooki.com/news/articleView.html?idxno=1116400
#
# Index: 876, Content: 주소서울특별시 종로구 청계천로 11 청계한국빌딩 (서린동)제호머니투데이등록번호서울 아 01084등록일2009.12.24사업자등록번호762-86-02890발행일2000.01.01ISSN2636-0055대표이사/발행인/편집인강호병대표번호02-724-7700청소년 보호책임자신택균머니투데이의 모든 기사(콘텐츠)는 저작권법의 보호를 받으며, 무단 전재 복사 배포 등을 금지합니다.COPYRIGHT © MONEYTODAY ALL RIGHTS RESERVED.
# http://news.mt.co.kr/mtview.php?no=2024081315330134591
#
# Index: 877, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# http://www.ftoday.co.kr/news/articleView.html?idxno=327052
#
# Index: 878, Content: 삭제한 댓글은 다시 복구할 수 없습니다.그래도 삭제하시겠습니까?
# https://www.newsclaim.co.kr/news/articleView.html?idxno=3034113
#
# Index: 879, Content: ‘변동성 장세’ 비트코인 “장기적 안전자산”되나[미국주식] 증시, 금리에 ‘시큰둥’? 알파벳·엔비디아·테슬라 등 주가 엇갈려엔화 환율 다시 오르나…IB들 “3개월 뒤 달러당 153엔”“이러다 7% 될라”…자고 일어나면 오르는 주담대 금리‘옥석 가리기 본격화’ 화장품주, 2분기 실적 따라 희비 엇갈려
# https://www.ekn.kr/web/view.php?key=20240813022232987
#
# Index: 880, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISX20240812_0002846742
#
# Index: 883, Content: 매체정보03973 서울 마포구 월드컵북로 106 미디어타워 8층대표전화 : (02)326-5117팩스 : (02)326-5118제호 : 프레스맨등록번호 : 서울 아 02434등록일 : 2013-01-18발행일 : 2013-01-18발행·편집인 : 이석호편집국장 : 홍성인청소년보호책임자 : 김승종SSN 2636-1930Copyright © 2024 프레스맨.Allrights reserved. mail toadmin@pressman.kr
# https://www.pressman.kr/news/articleView.html?idxno=83667
#
# Index: 885, Content: 광복회 주최 광복절 기념식광복절 전야음악회 ‘8.15 서울 마이 소울(Seoul My Soul)’독립유공자 유족회원증 받은 허미미 선수독립유공자 후손들과 함께한 윤석열 대통령'광복절, 그날의 함성을 기억하며'일본군 위안부 피해자 기림의 날 기념식
# https://www.newspim.com/news/view/20240813000271
#
# Index: 889, Content: 이 뉴스 공유하기닫기카카오톡페이스북X카카오스토리페이스북메신저네이버밴드네이버블로그URL복사
# https://www.yna.co.kr/view/AKR20240810041400002?input=1195m
#
# Index: 890, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486036
#
# Index: 891, Content: 오늘의 헤드라인" 대통령 경축사에 엇갈린 여야"새로운 비전" vs "日 언급 못해"여야는 15일 윤석열 대통령의 광복절 경축사에 대해 엇갈린 평가를 냈다. 국민의힘은 윤 대통령이 통일을 위한 새로운 비전을 제시했다고 호평한 반면 민주당 등 야당은 일제에 관한 과거사를 언급하지 않았다며 최악의 경축사라고 혹평했다.
#
# 한지아 국민의힘 수석대변인은 논평을 내고 "윤 대통령께서는 오늘 '더 큰 자유와 기회를 누리는' 통일 대한민국을 향한
# https://www.newsis.com/view/NISI20240813_0020486037
#
# Index: 892, Content: ■금감원, 우리銀 현장검사전체 616억 중 198억 연체본점 승인 없이 추가 대출손실 예상액만 최대 158억임직원 8명 면직 등 제재
# https://www.sedaily.com/NewsView/2DCZ5BB7NK
#
# Index: 897, Content: 동아닷컴주소 서울특별시 서대문구 충정로 29전화번호 02-360-0400등록번호 서울아00741발행일자 1996.06.18등록일자 2009.01.16발행·편집인 이명건
# https://www.donga.com/news/Economy/article/all/20240813/126514857/2
